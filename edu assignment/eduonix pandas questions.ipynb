# %% [markdown]
# # LOAD THE DATASET FROM THE GIVEN BELOW LINK.

# %% [markdown]
# https://drive.google.com/file/d/1RWvyhf9AcDZsSB5xVVgzsbHI1m4sFBJf/view?usp=share_link

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\91737\Downloads\chipotle (3).csv")
df['Price'] = df['item_price'].str[1:].astype(float)
df['Count'] = 1
df['Per Item Price'] = df['Price']/df['quantity']
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  Price  \
# 0                                                   NaN     $2.39    2.39
# ...

# %% [markdown]
# # USING PANDAS FUNCTION CALCULATE HOW MANY PRODUCTS COSTS MORE THAN $10?

# %%
above_10 = df.loc[(df['Per Item Price']>=10)].count().max()

# %%
print('total products',above_10,'are less than 10 dollers')
# Out:
# total products 1034 are less than 10 dollers

# %% [markdown]
# # What is the price of each item?

# %%
df3=df.groupby(['item_name','item_price']).mean()

# %%
df3
# Out:
#                                  order_id  quantity  Price  Count  \
# item_name         item_price
# 6 Pack Soft Drink $12.98      1360.000000       2.0  12.98    1.0
#                   $6.49        961.547170       1.0   6.49    1.0
# Barbacoa Bowl     $11.48       456.333333       1.0  11.48    1.0
#                   $11.49      1793.000000       1.0  11.49    1.0
#                   $11.75      1064.350000       1.0  11.75    1.0
# ...                                   ...       ...    ...    ...
# Veggie Salad Bowl $8.75       1093.625000       1.0   8.75    1.0
# Veggie Soft Tacos $11.25       496.000000       1.0  11.25    1.0
#                   $16.98      1559.000000       2.0  16.98    1.0
#                   $8.49        849.500000       1.0   8.49    1.0
#                   $8.75        635.000000       1.0   8.75    1.0
#
#                               Per Item Price
# item_name         item_price
# 6 Pack Soft Drink $12.98                6.49
# ...

# %% [markdown]
# # Which is the Most Expensive Item?

# %%
x = df['item_price'].max()
df.loc[df['item_price'] == x]
# Out:
#       order_id  quantity            item_name  \
# 607        250         1     Steak Salad Bowl
# 1418       576         1  Barbacoa Salad Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 2624      1042         1     Steak Salad Bowl
# 3098      1235         1     Steak Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# 3356      1346         1  Barbacoa Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4547      1807         1     Steak Salad Bowl
# 4572      1818         1     Steak Salad Bowl
#
#                                      choice_description item_price  Price  \
# ...
